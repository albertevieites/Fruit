# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

# %%
data = pd.read_excel("../data/raw/entrenamiento.xlsx")
data = data.rename(columns={"C7.1": "C8", "des": "QUALITY"})
features = data.drop(columns=["QUALITY"])
target = data["QUALITY"]

# %%
data.describe().T
# Out:
#           count       mean         std       min        25%        50%  \
# C1       3684.0   6.857166    0.846430  3.800000   6.300000   6.800000
# C2       3664.0   0.421440    0.988207  0.076961   0.190620   0.231112
# C3       3648.0   0.284054    0.086887  0.000000   0.239017   0.277632
# C4       3636.0   6.424642    5.084063  0.600000   1.700000   5.300000
# C5       3659.0  40.685294   25.106022  0.020000  33.000000  41.000000
# C6       3655.0  35.216142   17.167346  2.000000  23.000000  34.000000
# C7       3645.0   4.885591    0.341723  2.302585   4.691348   4.912655
# C8       3646.0  65.824651  245.359289  0.987110   0.991800   0.994100
# C9       3658.0   3.188291    0.152155  2.720000   3.090000   3.180000
# C10      3639.0   0.395421    0.074535  0.198851   0.343590   0.385262
# C11      3658.0  10.491607    1.218126  8.000000   9.400000  10.300000
# QUALITY  3918.0   5.870342    0.887340  3.000000   5.000000   6.000000
#
#                75%          max
# ...

# %%
# Visualize the distribution of the data for each feature
plt.figure(figsize=(15, 10))

# Plotting the distribution of each column
for i, column in enumerate(features.columns, 1):
    plt.subplot(3, 4, i)
    sns.histplot(features[column], bins=30, kde=True)
    plt.title(f"Distribution of {column}")
    plt.tight_layout()
    plt.grid(False)
    sns.despine()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Lista de columnas numéricas
numeric_columns = data.columns[:-1]  # Excluyendo la columna "QUALITY"

# Configuración de la visualización
plt.figure(figsize=(20, 15))
sns.set_style("whitegrid")

# Generar gráficos de distribución y boxplots
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(3, 4, i)
    sns.histplot(df[col], bins=30, kde=True, color='skyblue')
    sns.boxplot(x=df[col], color='red', width=0.2)
    plt.title(f'Distribution and Boxplot of {col}')
    plt.tight_layout()

plt.show()

# %%
# Visualización de la variable objetivo "QUALITY"

plt.figure(figsize=(12, 5))

# Conteo de valores
plt.subplot(1, 2, 1)
sns.countplot(data=df, x="QUALITY", palette="viridis")
plt.title("Count of each Quality")

# Distribución
plt.subplot(1, 2, 2)
sns.histplot(data["QUALITY"], bins=30, kde=True, color='skyblue')
plt.title("Distribution of Quality")

plt.tight_layout()
plt.grid()
plt.show()
