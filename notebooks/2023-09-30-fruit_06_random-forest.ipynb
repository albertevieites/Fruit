# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import xgboost as xgb

# %%
df= pd.read_excel("../data/raw/entrenamiento.xlsx")
df= df.rename(columns={"C7.1": "C8", "des": "QUALITY"})

# %%
high_values_train = df["C8"] > 900
df.loc[high_values_train, "C8"] = df.loc[high_values_train, "C8"] / 1000

# %%
def impute_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = (data[column] < lower_bound) | (data[column] > upper_bound)

    # Impute outliers with the median of the column
    data.loc[outliers, column] = data[column].median()
    return data


# Impute outliers in the dataset using IQR method
df_imputed_outliers = df.copy()
for column in df.columns:
    if df[column].dtype != 'object':  # Apply only for numerical columns
        df_imputed_outliers = impute_outliers_iqr(df_imputed_outliers, column)

# %%
# Impute missing values using median for predictor columns (excluding 'des' or 'QUALITY')
for column in df_imputed_outliers.columns:
    if column != "des" and df_imputed_outliers[
        column].dtype != 'object':  # Exclude target column and non-numerical columns
        median_value = df_imputed_outliers[column].median()
        df_imputed_outliers[column].fillna(median_value, inplace=True)

# Check if there are any missing values left
remaining_missing_values = df_imputed_outliers.isnull().sum()
remaining_missing_values[remaining_missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
df_completed = df_imputed_outliers.copy()
# Separar las características y la variable objetivo
X = df_completed.drop("QUALITY", axis=1)
y = df_completed["QUALITY"]

# Estandarizar las características
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)
## Splitting the DataFrame
# Dividir los datos en conjuntos de entrenamiento y prueba
X_train_std, X_test_std, y_train, y_test = train_test_split(X_standardized, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Definir el rango de hiperparámetros
param_dist = {
    'n_estimators': np.arange(50, 501, 50),
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': np.arange(3, 21),
    'min_samples_split': np.arange(2, 21),
    'min_samples_leaf': np.arange(1, 21),
    'bootstrap': [True, False]
}

# Iniciar RandomizedSearchCV
rf = RandomForestRegressor(random_state=42)
rf_search = RandomizedSearchCV(
    rf, param_distributions=param_dist, n_iter=100, cv=5, verbose=2, random_state=42, n_jobs=-1, scoring='neg_mean_absolute_error'
)

# Ajustar RandomizedSearchCV al conjunto de entrenamiento
rf_search.fit(X_train_std, y_train)

# Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros:", rf_search.best_params_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=15, min_samples_split=9, n_estimators=150; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=450; total time=   1.3s
# [CV] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=11, n_estimators=450; total time=   1.4s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=12, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=12, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=12, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=12, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=12, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.7s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=19, min_samples_split=14, n_estimators=450; total time=   1.0s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=15, min_samples_split=6, n_estimators=150; total time=   0.5s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=11, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=9, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=9, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=9, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=16, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=11, min_samples_split=15, n_estimators=350; total time=   1.0s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=17, min_samples_split=13, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=13, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=19, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=19, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=19, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=19, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=19, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=16, min_samples_split=16, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=16, min_samples_split=16, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=16, min_samples_split=16, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=16, min_samples_split=16, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=16, min_samples_split=16, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=9, min_samples_split=16, n_estimators=450; total time=   0.6s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=13, min_samples_split=20, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=11, min_samples_split=19, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=False, max_depth=19, max_features=auto, min_samples_leaf=5, min_samples_split=12, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=13, min_samples_split=20, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=450; total time=   1.6s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=17, min_samples_split=7, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=17, min_samples_split=7, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=14, min_samples_split=11, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=350; total time=   0.5s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=350; total time=   0.5s
# [CV] END bootstrap=False, max_depth=19, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=150; total time=   0.6s
# [CV] END bootstrap=False, max_depth=19, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=150; total time=   0.6s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=19, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=20, min_samples_split=14, n_estimators=450; total time=   1.3s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=350; total time=   1.1s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=14, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=11, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=16, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=False, max_depth=16, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=16, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=16, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=16, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=16, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=13, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=250; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=9, min_samples_split=16, n_estimators=450; total time=   0.6s
# [CV] END bootstrap=False, max_depth=17, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=False, max_depth=17, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=False, max_depth=17, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=False, max_depth=17, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=False, max_depth=17, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=450; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=450; total time=   1.6s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=17, min_samples_split=7, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=17, min_samples_split=7, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=17, min_samples_split=7, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=17, min_samples_split=7, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=19, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=150; total time=   0.6s
# [CV] END bootstrap=False, max_depth=19, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=150; total time=   0.6s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=18, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=150; total time=   0.7s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=150; total time=   0.7s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=20, min_samples_split=4, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=20, min_samples_split=4, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=400; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=350; total time=   1.1s
# [CV] END bootstrap=False, max_depth=3, max_features=auto, min_samples_leaf=13, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=19, min_samples_split=14, n_estimators=450; total time=   1.1s
# [CV] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=16, min_samples_split=12, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=16, min_samples_split=12, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=16, min_samples_split=12, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=16, min_samples_split=12, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=16, min_samples_split=12, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=11, min_samples_split=2, n_estimators=450; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=16, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=17, min_samples_split=13, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=13, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=250; total time=   0.5s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=13, min_samples_split=20, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=11, min_samples_split=19, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=350; total time=   0.6s
# [CV] END bootstrap=False, max_depth=19, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=150; total time=   0.6s
# [CV] END bootstrap=True, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=19, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=150; total time=   0.6s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=15, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=False, max_depth=14, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=   0.0s
# [CV] END bootstrap=False, max_depth=14, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=   0.0s
# [CV] END bootstrap=False, max_depth=14, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=   0.0s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=15, min_samples_split=9, n_estimators=150; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=450; total time=   1.3s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=350; total time=   0.8s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=14, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=350; total time=   0.5s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=13, min_samples_split=11, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=6, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=13, min_samples_split=5, n_estimators=450; total time=   1.6s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=8, n_estimators=250; total time=   1.2s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=11, min_samples_split=15, n_estimators=350; total time=   1.0s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=17, min_samples_split=13, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=250; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=9, min_samples_split=16, n_estimators=450; total time=   0.6s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=15, min_samples_split=9, n_estimators=150; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=450; total time=   1.6s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=11, n_estimators=450; total time=   1.4s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=14, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=18, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=19, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=19, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=20, min_samples_split=14, n_estimators=450; total time=   1.3s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=20, min_samples_split=14, n_estimators=450; total time=   1.2s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=14, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=11, min_samples_split=2, n_estimators=450; total time=   1.2s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=16, min_samples_split=13, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=16, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=16, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=16, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=18, n_estimators=450; total time=   2.0s
# [CV] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=11, n_estimators=450; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=11, n_estimators=450; total time=   1.4s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=13, min_samples_split=11, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=13, min_samples_split=11, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=13, min_samples_split=11, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=13, min_samples_split=11, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=15, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=20, min_samples_split=14, n_estimators=450; total time=   1.3s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=3, min_samples_split=17, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=18, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=False, max_depth=3, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=150; total time=   0.0s
# [CV] END bootstrap=False, max_depth=3, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=150; total time=   0.0s
# [CV] END bootstrap=False, max_depth=3, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=150; total time=   0.0s
# [CV] END bootstrap=False, max_depth=3, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=150; total time=   0.0s
# [CV] END bootstrap=False, max_depth=3, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=150; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=350; total time=   0.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=11, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=17, min_samples_split=7, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=150; total time=   0.7s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=150; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   0.7s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=6, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=350; total time=   1.1s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=13, min_samples_split=5, n_estimators=450; total time=   1.6s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=19, min_samples_split=13, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=3, min_samples_split=13, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=15, min_samples_split=9, n_estimators=150; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=450; total time=   1.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=350; total time=   0.8s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=350; total time=   0.9s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=auto, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=15, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=9, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=15, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=19, min_samples_split=20, n_estimators=350; total time=   0.7s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=6, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=19, min_samples_split=14, n_estimators=450; total time=   1.1s
# ...
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=14, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=19, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=15, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=19, min_samples_split=20, n_estimators=350; total time=   0.8s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=16, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=14, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=11, min_samples_split=2, n_estimators=450; total time=   1.2s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=19, min_samples_split=13, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=18, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=450; total time=   1.6s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=15, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=15, min_samples_split=19, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=6, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=auto, min_samples_leaf=11, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=14, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=11, min_samples_split=2, n_estimators=450; total time=   1.2s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=2, min_samples_split=18, n_estimators=450; total time=   1.6s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=450; total time=   1.5s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=19, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   0.7s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=18, max_features=auto, min_samples_leaf=12, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=20, min_samples_split=14, n_estimators=450; total time=   1.3s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=350; total time=   1.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, min_samples_leaf=19, min_samples_split=14, n_estimators=450; total time=   1.1s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=15, min_samples_split=6, n_estimators=150; total time=   0.5s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=11, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=9, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=9, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=9, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=9, min_samples_split=16, n_estimators=250; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=16, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=11, min_samples_split=15, n_estimators=350; total time=   1.0s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=17, min_samples_split=13, n_estimators=50; total time=   0.1s
# /home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 170 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 66 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 104 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/alberte/Desktop/Fruit/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [-0.50540519 -0.51966008 -0.52121123         nan -0.52378849 -0.51651355
#  -0.49875788         nan -0.52714078         nan -0.50881503 -0.51232466
#          nan -0.49281049 -0.51120892 -0.51120581 -0.53686358 -0.51295853
#  -0.51788553         nan         nan         nan -0.48802567         nan
#  -0.51232838 -0.51883207         nan -0.54002264 -0.56278772         nan
#  -0.50305153 -0.5226748  -0.49972208 -0.50960198 -0.49149837 -0.49273361
#          nan -0.51208706         nan -0.51868376 -0.52093641 -0.50495629
#  -0.51217191 -0.50137847 -0.5273663  -0.52044581 -0.50973606 -0.54134736
#          nan -0.52603483         nan -0.56075487 -0.53606031 -0.52750924
#  -0.51897266 -0.50794704 -0.51940639         nan         nan -0.52634039
#          nan         nan -0.52880848         nan -0.5199714          nan
#  -0.51067817 -0.5197223  -0.51341337         nan -0.52628488 -0.51686097
#  -0.47726022 -0.5075183          nan         nan -0.52353031 -0.50737587
#          nan         nan -0.51484589 -0.5187323          nan -0.52137176
#  -0.5051727          nan         nan -0.55226728 -0.50744093         nan
#  -0.53461201 -0.52955404         nan         nan -0.53028432 -0.5513497
#          nan         nan         nan -0.55915679]
#   warnings.warn(
# Mejores hiperparámetros: {'n_estimators': 250, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 17, 'bootstrap': False}

# %%
# Evaluar el modelo con los hiperparámetros óptimos en el conjunto de entrenamiento
best_rf = rf_search.best_estimator_
train_predictions = best_rf.predict(X_train_std)
mae = mean_absolute_error(y_train, train_predictions)
print(f"MAE con hiperparámetros optimizados: {mae:.4f}")
# Out:
# MAE con hiperparámetros optimizados: 0.1842

# %%
from sklearn.model_selection import cross_val_score

# Definir el modelo Random Forest con hiperparámetros optimizados
optimized_rf = RandomForestRegressor(
    n_estimators=100,
    max_depth=9,
    min_samples_split=4,
    min_samples_leaf=2,
    random_state=42
)

# Realizar validación cruzada con 5 particiones
mae_scores = -cross_val_score(optimized_rf, X_train_std, y_train, cv=5, scoring='neg_mean_absolute_error')

# Mostrar los resultados de cada iteración
print(f"MAE scores from cross-validation: {mae_scores}")

# Calcular y mostrar el MAE medio y la desviación estándar de los MAE
mean_mae = mae_scores.mean()
std_mae = mae_scores.std()
print(f"Mean MAE score: {mean_mae}")
print(f"Standard Deviation of MAE scores: {std_mae}")
# Out:
# MAE scores from cross-validation: [0.50999777 0.51509413 0.49633356 0.49567327 0.52110788]
# Mean MAE score: 0.5076413226835612
# Standard Deviation of MAE scores: 0.010134546807913956
